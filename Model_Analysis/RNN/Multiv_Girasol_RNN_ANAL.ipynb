# %%
import keras
import pandas as pd
from keras import layers
import tensorflow as tf

import matplotlib.pyplot as plt

from sklearn.metrics import mean_squared_error
import numpy as np
# Out:
# 2025-01-05 03:50:36.289775: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1736049036.298916  545976 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1736049036.301685  545976 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-01-05 03:50:36.312037: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Sequential
from tensorflow.keras.models import load_model
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import mean_squared_error as mse
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.layers import Dense, InputLayer, Bidirectional,LSTM, Dropout, SimpleRNN, GRU
# from keras import ops
import numpy as np

# %%
DC_POWER_INDEX = 0
LEARNING_RATE = 0.001
RANDOM_STATE = 44
START_TIME = '2020-06-07 00:30:00'
END_TIME = '2020-06-07 04:00:00'
NUMBER_OF_FEATURES = 8
BATCH_SIZE = 1024
# Training window
MULTIV_TRAINING_WINDOW = 8

def fix_randomness():
    tf.random.set_seed(RANDOM_STATE)

    from numpy.random import seed
    seed(RANDOM_STATE)
    keras.utils.set_random_seed(RANDOM_STATE)

fix_randomness()

# %% [markdown]
# MULTIVARIATE

# %%
EPOCHS = 500
MULTIV_TRAINING_WINDOW = 40
lead_time = 20

# %%
# Creating the model input for multivariate forecasting
def df_to_model_input2(df_np, col_index, window_size):
    df_np = df_np.to_numpy()
    x = []
    y = []

    for i in range(len(df_np) - window_size - lead_time):
        row = [r for r in df_np[i:i+window_size]]
        x.append(row)

        label = df_np[i+lead_time+window_size][col_index]
        y.append(label)

    return np.array(x), np.array(y)

# %%
multiv_teacher_path = 'models/girasol/multiv_teacher_model.keras'
multiv_student_path = 'models/girasol/multiv_student_model.keras'
distilled_student_path = 'models/girasol/distilled_multiv_student_model.keras'

# %%
train = pd.read_csv('/.../girasol_met/train.csv')
test = pd.read_csv('/.../girasol_met/val.csv')

# %%
NUMBER_OF_FEATURES = len(train.columns)

# %%
scaler = MinMaxScaler()
train = pd.DataFrame(scaler.fit_transform(train), columns=train.columns)
test = pd.DataFrame(scaler.transform(test), columns=test.columns)

# %%
def get_train_test_val(x, y):
    return x[:train_len], y[:train_len], x[train_len:], y[train_len:]

x, y = df_to_model_input2(train, 7, MULTIV_TRAINING_WINDOW)

ds_len = len(y)
train_len = int(0.8*ds_len)

x_train, y_train, x_val, y_val = get_train_test_val(x, y)
x_test, y_test = df_to_model_input2(test, 7, MULTIV_TRAINING_WINDOW)

# %%
from sklearn.metrics import mean_absolute_percentage_error
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error

def calculate_mape(scaler, y_pred_scaled, target_column_index=-1):

    # Create dummy arrays to match the scaler's expected input shape
    dummy_data_pred = np.zeros((y_pred_scaled.shape[0], NUMBER_OF_FEATURES))
    dummy_data_test = np.zeros((y_test.shape[0], NUMBER_OF_FEATURES))

    # Insert the predicted values and y_test into the correct column
    dummy_data_pred[:, target_column_index] = y_pred_scaled[:, 0]
    dummy_data_test[:, target_column_index] = y_test[:] # it kept that way to be able to modify if needed

    # Perform inverse transform to get the unscaled predictions and y_test
    unscaled_predictions = scaler.inverse_transform(dummy_data_pred)[:, target_column_index]
    y_test_unscaled = scaler.inverse_transform(dummy_data_test)[:, target_column_index]



    mape = mean_absolute_percentage_error(y_test_unscaled, unscaled_predictions)
    return mape

def calculate_metrics(y_true, y_pred):
    """
    Calculate NMSE, NRMSE, and NMAE normalized by the average of true values.
    
    Parameters:
        y_true (array-like): True values.
        y_pred (array-like): Predicted values.
        
    Returns:
        dict: A dictionary containing NMSE, NRMSE, and NMAE.
    """
    # Convert inputs to numpy arrays for consistency
    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
    
    # Mean Squared Error (MSE) and Mean Absolute Error (MAE) using sklearn
    mse = mean_squared_error(y_true, y_pred)
    mae = mean_absolute_error(y_true, y_pred)

    mape = calculate_mape(scaler=scaler, y_pred_scaled=y_pred)*100
    # Variance and mean of true values
    avg_true = np.mean(y_true)
    
    # Calculate metrics
    nrmse = np.sqrt(mse) / avg_true
    nmae = mae / avg_true

    print(f"NRMSE (Normalized Root Mean Squared Error): {nrmse:.4f}")
    print(f"NMAE (Normalized Mean Absolute Error): {nmae:.4f}")
    print(f"MAPE (Mean Absolute Percentage Error): {mape:.4f}") 
    
    # Return metrics as a dictionary
    return nrmse, nmae, mape

# %%
columns = ['Hidden Units', 'Dense Units', 'RMSE']
results_df = pd.DataFrame(columns=columns)

# %%
from sklearn.preprocessing import MinMaxScaler
import os

# Check if the 'results' directory exists in the current working directory
if not os.path.exists('results'):
    # If the directory does not exist, you can create it
    os.makedirs('results')

script_name = 'results/multiv_girasol_analysis'
def run_student_multiv(hidden_unit, dense_param):

    global results_df  # To modify the global DataFrame

    # Create the model
    model = Sequential()
    model.add(InputLayer((MULTIV_TRAINING_WINDOW, NUMBER_OF_FEATURES)))
    model.add(SimpleRNN(hidden_unit))
    model.add(Dropout(0.5))
    model.add(Dense(dense_param, 'relu'))
    model.add(Dense(1, 'linear'))

    # Model checkpoint
    model_file = multiv_student_path

    cp = ModelCheckpoint(model_file, save_best_only=True)

    # Early stopping to prevent overfitting
    early_stopping = EarlyStopping(
        monitor='val_loss', 
        patience=5,  # Number of epochs with no improvement after which training will be stopped
        restore_best_weights=True  # Restore the weights of the best epoch after stopping
    )

    # Compile the model
    model.compile(
        loss=MeanSquaredError(),
        optimizer=Adam(learning_rate=LEARNING_RATE),
        metrics=[MeanSquaredError()]
    )
   
    # Train the model
    model.fit(
        x_train, y_train,
        validation_data=(x_val, y_val),
        batch_size=BATCH_SIZE,
        epochs=EPOCHS,
        callbacks=[cp, early_stopping]
    )

    # Make predictions on the scaled test set
    y_pred = model.predict(x_test)

    nrmse, nmae, mape = calculate_metrics(y_test, y_pred)

    # Add a new row to the DataFrame with all metrics
    new_row = pd.DataFrame({
        'Hidden Units': [hidden_unit], 
        'Dense Units': [dense_param], 
        'NRMSE': [nrmse], 
        'NMAE': [nmae], 
        'MAPE': [mape]
    })

    # Concatenate the new row to the results DataFrame
    results_df = pd.concat([results_df, new_row], ignore_index=True)

    # Save the DataFrame to a CSV file after each run
    results_df.to_csv(f'{script_name}.csv', index=False)

    calculate_mape(scaler=scaler, y_pred_scaled=y_pred)

    # Return a summary string with all the metrics
    return f"Hidden Units: {hidden_unit}, Dense Units: {dense_param}, NRMSE: {nrmse:.5f}, NMAE: {nmae:.5f}, MAPE: {mape:.5f}"


hidden_units = [16, 32, 64, 128, 512]
dense_params = [8]

rmse_list = []
for i in hidden_units:
    for j in dense_params:
        RANDOM_STATE = 44
        tf.random.set_seed(RANDOM_STATE)
        from numpy.random import seed
        seed(RANDOM_STATE)
        keras.utils.set_random_seed(RANDOM_STATE)

        s = run_student_multiv(i,j)
        rmse_list.append(s)

rmse_list
# Out:
# I0000 00:00:1736049039.004484  545976 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9711 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060, pci bus id: 0000:06:00.0, compute capability: 8.6
# Epoch 1/500
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1736049047.119134  546120 service.cc:148] XLA service 0x7f2bd00041e0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1736049047.119168  546120 service.cc:156]   StreamExecutor device (0): NVIDIA GeForce RTX 3060, Compute Capability 8.6
# 2025-01-05 03:50:47.139120: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1736049047.212851  546120 cuda_dnn.cc:529] Loaded cuDNN version 90300
#  7/37 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.3652 - mean_squared_error: 0.3652
# I0000 00:00:1736049047.739723  546120 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 0.2566 - mean_squared_error: 0.2565 - val_loss: 0.1434 - val_mean_squared_error: 0.1328
# Epoch 2/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0809 - mean_squared_error: 0.0808 - val_loss: 0.0970 - val_mean_squared_error: 0.0894
# Epoch 3/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0586 - mean_squared_error: 0.0586 - val_loss: 0.0731 - val_mean_squared_error: 0.0680
# Epoch 4/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0436 - mean_squared_error: 0.0436 - val_loss: 0.0484 - val_mean_squared_error: 0.0449
# Epoch 5/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0320 - mean_squared_error: 0.0320 - val_loss: 0.0348 - val_mean_squared_error: 0.0321
# Epoch 6/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0260 - mean_squared_error: 0.0260 - val_loss: 0.0308 - val_mean_squared_error: 0.0284
# Epoch 7/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0213 - mean_squared_error: 0.0213 - val_loss: 0.0243 - val_mean_squared_error: 0.0226
# Epoch 8/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0190 - mean_squared_error: 0.0190 - val_loss: 0.0206 - val_mean_squared_error: 0.0193
# Epoch 9/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0172 - mean_squared_error: 0.0172 - val_loss: 0.0179 - val_mean_squared_error: 0.0170
# Epoch 10/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0156 - mean_squared_error: 0.0155 - val_loss: 0.0164 - val_mean_squared_error: 0.0158
# Epoch 11/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0143 - mean_squared_error: 0.0143 - val_loss: 0.0157 - val_mean_squared_error: 0.0150
# Epoch 12/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0132 - mean_squared_error: 0.0132 - val_loss: 0.0149 - val_mean_squared_error: 0.0142
# Epoch 13/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0122 - mean_squared_error: 0.0122 - val_loss: 0.0155 - val_mean_squared_error: 0.0147
# Epoch 14/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0118 - mean_squared_error: 0.0118 - val_loss: 0.0144 - val_mean_squared_error: 0.0137
# Epoch 15/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0113 - mean_squared_error: 0.0113 - val_loss: 0.0154 - val_mean_squared_error: 0.0146
# Epoch 16/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0105 - mean_squared_error: 0.0105 - val_loss: 0.0159 - val_mean_squared_error: 0.0151
# Epoch 17/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0102 - mean_squared_error: 0.0102 - val_loss: 0.0159 - val_mean_squared_error: 0.0152
# Epoch 18/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0099 - mean_squared_error: 0.0099 - val_loss: 0.0155 - val_mean_squared_error: 0.0148
# Epoch 19/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0097 - mean_squared_error: 0.0097 - val_loss: 0.0152 - val_mean_squared_error: 0.0145
# 1453/1453 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step
# NRMSE (Normalized Root Mean Squared Error): 0.2221
# NMAE (Normalized Mean Absolute Error): 0.1791
# MAPE (Mean Absolute Percentage Error): 18.5416
# Epoch 1/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.0740 - mean_squared_error: 0.0740 - val_loss: 0.0177 - val_mean_squared_error: 0.0169
# Epoch 2/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0279 - mean_squared_error: 0.0279 - val_loss: 0.0086 - val_mean_squared_error: 0.0086
# Epoch 3/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0190 - mean_squared_error: 0.0190 - val_loss: 0.0071 - val_mean_squared_error: 0.0073
# Epoch 4/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0151 - mean_squared_error: 0.0151 - val_loss: 0.0062 - val_mean_squared_error: 0.0065
# Epoch 5/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0128 - mean_squared_error: 0.0128 - val_loss: 0.0064 - val_mean_squared_error: 0.0068
# Epoch 6/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0116 - mean_squared_error: 0.0116 - val_loss: 0.0057 - val_mean_squared_error: 0.0061
# Epoch 7/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0106 - mean_squared_error: 0.0106 - val_loss: 0.0054 - val_mean_squared_error: 0.0061
# Epoch 8/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0100 - mean_squared_error: 0.0100 - val_loss: 0.0056 - val_mean_squared_error: 0.0061
# Epoch 9/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0093 - mean_squared_error: 0.0093 - val_loss: 0.0056 - val_mean_squared_error: 0.0062
# Epoch 10/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0090 - mean_squared_error: 0.0090 - val_loss: 0.0052 - val_mean_squared_error: 0.0059
# Epoch 11/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0086 - mean_squared_error: 0.0086 - val_loss: 0.0051 - val_mean_squared_error: 0.0060
# Epoch 12/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0085 - mean_squared_error: 0.0085 - val_loss: 0.0053 - val_mean_squared_error: 0.0059
# Epoch 13/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0051 - val_mean_squared_error: 0.0058
# Epoch 14/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0080 - mean_squared_error: 0.0080 - val_loss: 0.0050 - val_mean_squared_error: 0.0057
# Epoch 15/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0078 - mean_squared_error: 0.0078 - val_loss: 0.0050 - val_mean_squared_error: 0.0056
# Epoch 16/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0077 - mean_squared_error: 0.0077 - val_loss: 0.0050 - val_mean_squared_error: 0.0058
# Epoch 17/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0076 - mean_squared_error: 0.0076 - val_loss: 0.0050 - val_mean_squared_error: 0.0058
# Epoch 18/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0075 - mean_squared_error: 0.0075 - val_loss: 0.0050 - val_mean_squared_error: 0.0059
# Epoch 19/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0075 - mean_squared_error: 0.0075 - val_loss: 0.0048 - val_mean_squared_error: 0.0056
# Epoch 20/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0072 - mean_squared_error: 0.0072 - val_loss: 0.0049 - val_mean_squared_error: 0.0056
# Epoch 21/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0072 - mean_squared_error: 0.0072 - val_loss: 0.0048 - val_mean_squared_error: 0.0055
# Epoch 22/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0072 - mean_squared_error: 0.0072 - val_loss: 0.0049 - val_mean_squared_error: 0.0056
# Epoch 23/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0071 - mean_squared_error: 0.0071 - val_loss: 0.0049 - val_mean_squared_error: 0.0055
# Epoch 24/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0070 - mean_squared_error: 0.0070 - val_loss: 0.0048 - val_mean_squared_error: 0.0053
# Epoch 25/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0069 - mean_squared_error: 0.0069 - val_loss: 0.0048 - val_mean_squared_error: 0.0053
# Epoch 26/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0068 - mean_squared_error: 0.0068 - val_loss: 0.0050 - val_mean_squared_error: 0.0055
# Epoch 27/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0068 - mean_squared_error: 0.0068 - val_loss: 0.0048 - val_mean_squared_error: 0.0054
# Epoch 28/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0068 - mean_squared_error: 0.0068 - val_loss: 0.0048 - val_mean_squared_error: 0.0053
# Epoch 29/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0067 - mean_squared_error: 0.0067 - val_loss: 0.0047 - val_mean_squared_error: 0.0052
# Epoch 30/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0067 - mean_squared_error: 0.0067 - val_loss: 0.0047 - val_mean_squared_error: 0.0053
# Epoch 31/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0066 - mean_squared_error: 0.0066 - val_loss: 0.0048 - val_mean_squared_error: 0.0053
# Epoch 32/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0066 - mean_squared_error: 0.0066 - val_loss: 0.0048 - val_mean_squared_error: 0.0053
# Epoch 33/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0066 - mean_squared_error: 0.0066 - val_loss: 0.0048 - val_mean_squared_error: 0.0053
# Epoch 34/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0065 - mean_squared_error: 0.0065 - val_loss: 0.0048 - val_mean_squared_error: 0.0053
# Epoch 35/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0065 - mean_squared_error: 0.0065 - val_loss: 0.0048 - val_mean_squared_error: 0.0052
# 1453/1453 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step
# NRMSE (Normalized Root Mean Squared Error): 0.1373
# NMAE (Normalized Mean Absolute Error): 0.0811
# MAPE (Mean Absolute Percentage Error): 10.7244
# Epoch 1/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.1217 - mean_squared_error: 0.1216 - val_loss: 0.0104 - val_mean_squared_error: 0.0102
# Epoch 2/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0259 - mean_squared_error: 0.0259 - val_loss: 0.0123 - val_mean_squared_error: 0.0120
# Epoch 3/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0171 - mean_squared_error: 0.0171 - val_loss: 0.0102 - val_mean_squared_error: 0.0101
# Epoch 4/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0141 - mean_squared_error: 0.0141 - val_loss: 0.0079 - val_mean_squared_error: 0.0080
# Epoch 5/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0126 - mean_squared_error: 0.0126 - val_loss: 0.0072 - val_mean_squared_error: 0.0073
# Epoch 6/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0119 - mean_squared_error: 0.0119 - val_loss: 0.0077 - val_mean_squared_error: 0.0078
# Epoch 7/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0109 - mean_squared_error: 0.0109 - val_loss: 0.0065 - val_mean_squared_error: 0.0067
# Epoch 8/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0105 - mean_squared_error: 0.0105 - val_loss: 0.0058 - val_mean_squared_error: 0.0061
# Epoch 9/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0102 - mean_squared_error: 0.0102 - val_loss: 0.0056 - val_mean_squared_error: 0.0059
# Epoch 10/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0097 - mean_squared_error: 0.0097 - val_loss: 0.0055 - val_mean_squared_error: 0.0058
# Epoch 11/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0094 - mean_squared_error: 0.0094 - val_loss: 0.0064 - val_mean_squared_error: 0.0065
# Epoch 12/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0092 - mean_squared_error: 0.0092 - val_loss: 0.0056 - val_mean_squared_error: 0.0059
# Epoch 13/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0086 - mean_squared_error: 0.0086 - val_loss: 0.0056 - val_mean_squared_error: 0.0059
# Epoch 14/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0084 - mean_squared_error: 0.0084 - val_loss: 0.0059 - val_mean_squared_error: 0.0061
# Epoch 15/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0083 - mean_squared_error: 0.0083 - val_loss: 0.0052 - val_mean_squared_error: 0.0056
# Epoch 16/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0081 - mean_squared_error: 0.0081 - val_loss: 0.0054 - val_mean_squared_error: 0.0057
# Epoch 17/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0078 - mean_squared_error: 0.0077 - val_loss: 0.0053 - val_mean_squared_error: 0.0057
# Epoch 18/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0076 - mean_squared_error: 0.0076 - val_loss: 0.0060 - val_mean_squared_error: 0.0062
# Epoch 19/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0075 - mean_squared_error: 0.0075 - val_loss: 0.0051 - val_mean_squared_error: 0.0055
# Epoch 20/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0074 - mean_squared_error: 0.0074 - val_loss: 0.0053 - val_mean_squared_error: 0.0056
# Epoch 21/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0073 - mean_squared_error: 0.0072 - val_loss: 0.0053 - val_mean_squared_error: 0.0056
# Epoch 22/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0072 - mean_squared_error: 0.0072 - val_loss: 0.0050 - val_mean_squared_error: 0.0053
# Epoch 23/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0070 - mean_squared_error: 0.0070 - val_loss: 0.0050 - val_mean_squared_error: 0.0054
# Epoch 24/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0069 - mean_squared_error: 0.0069 - val_loss: 0.0047 - val_mean_squared_error: 0.0052
# Epoch 25/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0069 - mean_squared_error: 0.0069 - val_loss: 0.0046 - val_mean_squared_error: 0.0051
# Epoch 26/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0068 - mean_squared_error: 0.0068 - val_loss: 0.0048 - val_mean_squared_error: 0.0052
# Epoch 27/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0068 - mean_squared_error: 0.0068 - val_loss: 0.0046 - val_mean_squared_error: 0.0051
# Epoch 28/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0067 - mean_squared_error: 0.0067 - val_loss: 0.0046 - val_mean_squared_error: 0.0050
# Epoch 29/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0066 - mean_squared_error: 0.0066 - val_loss: 0.0046 - val_mean_squared_error: 0.0051
# Epoch 30/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0067 - mean_squared_error: 0.0067 - val_loss: 0.0046 - val_mean_squared_error: 0.0050
# Epoch 31/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0065 - mean_squared_error: 0.0065 - val_loss: 0.0046 - val_mean_squared_error: 0.0050
# Epoch 32/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0066 - mean_squared_error: 0.0066 - val_loss: 0.0045 - val_mean_squared_error: 0.0049
# Epoch 33/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0065 - mean_squared_error: 0.0065 - val_loss: 0.0047 - val_mean_squared_error: 0.0051
# Epoch 34/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0064 - mean_squared_error: 0.0064 - val_loss: 0.0047 - val_mean_squared_error: 0.0051
# Epoch 35/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0065 - mean_squared_error: 0.0065 - val_loss: 0.0047 - val_mean_squared_error: 0.0051
# Epoch 36/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0065 - mean_squared_error: 0.0065 - val_loss: 0.0046 - val_mean_squared_error: 0.0051
# Epoch 37/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0064 - mean_squared_error: 0.0064 - val_loss: 0.0047 - val_mean_squared_error: 0.0051
# 1453/1453 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step
# NRMSE (Normalized Root Mean Squared Error): 0.1363
# NMAE (Normalized Mean Absolute Error): 0.0783
# MAPE (Mean Absolute Percentage Error): 10.4312
# Epoch 1/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 0.0664 - mean_squared_error: 0.0664 - val_loss: 0.0070 - val_mean_squared_error: 0.0071
# Epoch 2/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0134 - mean_squared_error: 0.0134 - val_loss: 0.0049 - val_mean_squared_error: 0.0053
# Epoch 3/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0110 - mean_squared_error: 0.0110 - val_loss: 0.0048 - val_mean_squared_error: 0.0052
# Epoch 4/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0098 - mean_squared_error: 0.0098 - val_loss: 0.0048 - val_mean_squared_error: 0.0052
# Epoch 5/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0094 - mean_squared_error: 0.0094 - val_loss: 0.0054 - val_mean_squared_error: 0.0057
# Epoch 6/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0090 - mean_squared_error: 0.0090 - val_loss: 0.0045 - val_mean_squared_error: 0.0051
# Epoch 7/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0087 - mean_squared_error: 0.0087 - val_loss: 0.0052 - val_mean_squared_error: 0.0056
# Epoch 8/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0084 - mean_squared_error: 0.0084 - val_loss: 0.0051 - val_mean_squared_error: 0.0054
# Epoch 9/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0083 - mean_squared_error: 0.0083 - val_loss: 0.0046 - val_mean_squared_error: 0.0053
# Epoch 10/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0084 - mean_squared_error: 0.0084 - val_loss: 0.0045 - val_mean_squared_error: 0.0050
# Epoch 11/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0079 - mean_squared_error: 0.0079 - val_loss: 0.0045 - val_mean_squared_error: 0.0051
# Epoch 12/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0078 - mean_squared_error: 0.0078 - val_loss: 0.0050 - val_mean_squared_error: 0.0053
# Epoch 13/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0076 - mean_squared_error: 0.0076 - val_loss: 0.0045 - val_mean_squared_error: 0.0050
# Epoch 14/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0076 - mean_squared_error: 0.0076 - val_loss: 0.0044 - val_mean_squared_error: 0.0050
# Epoch 15/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0074 - mean_squared_error: 0.0074 - val_loss: 0.0045 - val_mean_squared_error: 0.0050
# Epoch 16/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0073 - mean_squared_error: 0.0073 - val_loss: 0.0045 - val_mean_squared_error: 0.0051
# Epoch 17/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0073 - mean_squared_error: 0.0073 - val_loss: 0.0045 - val_mean_squared_error: 0.0050
# Epoch 18/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0072 - mean_squared_error: 0.0072 - val_loss: 0.0045 - val_mean_squared_error: 0.0051
# Epoch 19/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0072 - mean_squared_error: 0.0072 - val_loss: 0.0044 - val_mean_squared_error: 0.0049
# 1453/1453 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step
# NRMSE (Normalized Root Mean Squared Error): 0.1367
# NMAE (Normalized Mean Absolute Error): 0.0782
# MAPE (Mean Absolute Percentage Error): 10.6913
# Epoch 1/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 53ms/step - loss: 0.2954 - mean_squared_error: 0.2953 - val_loss: 0.0055 - val_mean_squared_error: 0.0062
# Epoch 2/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0195 - mean_squared_error: 0.0195 - val_loss: 0.0051 - val_mean_squared_error: 0.0056
# Epoch 3/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0113 - mean_squared_error: 0.0113 - val_loss: 0.0047 - val_mean_squared_error: 0.0052
# Epoch 4/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0096 - mean_squared_error: 0.0096 - val_loss: 0.0046 - val_mean_squared_error: 0.0051
# Epoch 5/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0090 - mean_squared_error: 0.0090 - val_loss: 0.0046 - val_mean_squared_error: 0.0051
# Epoch 6/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0083 - mean_squared_error: 0.0083 - val_loss: 0.0050 - val_mean_squared_error: 0.0058
# Epoch 7/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0086 - mean_squared_error: 0.0086 - val_loss: 0.0045 - val_mean_squared_error: 0.0050
# Epoch 8/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0076 - mean_squared_error: 0.0076 - val_loss: 0.0046 - val_mean_squared_error: 0.0051
# Epoch 9/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0079 - mean_squared_error: 0.0079 - val_loss: 0.0044 - val_mean_squared_error: 0.0050
# Epoch 10/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0076 - mean_squared_error: 0.0076 - val_loss: 0.0045 - val_mean_squared_error: 0.0052
# Epoch 11/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0075 - mean_squared_error: 0.0075 - val_loss: 0.0047 - val_mean_squared_error: 0.0055
# Epoch 12/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0075 - mean_squared_error: 0.0075 - val_loss: 0.0045 - val_mean_squared_error: 0.0050
# Epoch 13/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0071 - mean_squared_error: 0.0071 - val_loss: 0.0045 - val_mean_squared_error: 0.0050
# Epoch 14/500
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0074 - mean_squared_error: 0.0074 - val_loss: 0.0045 - val_mean_squared_error: 0.0050
# 1453/1453 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step
# NRMSE (Normalized Root Mean Squared Error): 0.1382
# NMAE (Normalized Mean Absolute Error): 0.0796
# MAPE (Mean Absolute Percentage Error): 10.6578
# ['Hidden Units: 16, Dense Units: 8, NRMSE: 0.22210, NMAE: 0.17912, MAPE: 18.54163',
#  'Hidden Units: 32, Dense Units: 8, NRMSE: 0.13725, NMAE: 0.08105, MAPE: 10.72444',
#  'Hidden Units: 64, Dense Units: 8, NRMSE: 0.13632, NMAE: 0.07830, MAPE: 10.43122',
#  'Hidden Units: 128, Dense Units: 8, NRMSE: 0.13671, NMAE: 0.07817, MAPE: 10.69133',
#  'Hidden Units: 512, Dense Units: 8, NRMSE: 0.13818, NMAE: 0.07964, MAPE: 10.65783']

# %%
rmse_list
# Out:
# ['Hidden Units: 16, Dense Units: 8, NRMSE: 0.22210, NMAE: 0.17912, MAPE: 18.54163',
#  'Hidden Units: 32, Dense Units: 8, NRMSE: 0.13725, NMAE: 0.08105, MAPE: 10.72444',
#  'Hidden Units: 64, Dense Units: 8, NRMSE: 0.13632, NMAE: 0.07830, MAPE: 10.43122',
#  'Hidden Units: 128, Dense Units: 8, NRMSE: 0.13671, NMAE: 0.07817, MAPE: 10.69133',
#  'Hidden Units: 512, Dense Units: 8, NRMSE: 0.13818, NMAE: 0.07964, MAPE: 10.65783']
